# %%
from elasticsearch import Elasticsearch
from elasticsearch.dsl import Search
import pandas as pd
import numpy as np
import urllib3
from datetime import datetime, timedelta
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
from pprint import pprint
import json

# %%
# Thiết lập kết nối đến Elasticsearch
conn = Elasticsearch(
    ['https://192.168.145.101:9200'], 
    ca_certs=False, 
    verify_certs=False,
    basic_auth=('jupyter', 'jupyter@seconi.com'),
)

print(conn.info())
# Out:
# {'name': 'sec-oni', 'cluster_name': 'securityonion', 'cluster_uuid': 'Mgfl_yJjRFaq4qzC1E76_g', 'version': {'number': '8.18.4', 'build_flavor': 'default', 'build_type': 'docker', 'build_hash': '43b24f613cf25fd3f3369df174e9535a99512aec', 'build_date': '2025-07-16T22:07:56.651816195Z', 'build_snapshot': False, 'lucene_version': '9.12.1', 'minimum_wire_compatibility_version': '7.17.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'You Know, for Search'}
# /home/mbelin/vdt/c2-beacon-detection/venv/lib/python3.12/site-packages/elasticsearch/_sync/client/__init__.py:403: SecurityWarning: Connecting to 'https://192.168.145.101:9200' using TLS with verify_certs=False is insecure
#   _transport = transport_class(

# %%
print(conn.indices.get_data_stream(name="logs-zeek*"))
# Out:
# {'data_streams': [{'name': 'logs-zeek-so', 'timestamp_field': {'name': '@timestamp'}, 'indices': [{'index_name': '.ds-logs-zeek-so-2025.09.19-000001', 'index_uuid': 'AmX3Qj2cRRGL-CeagnruSQ', 'prefer_ilm': True, 'ilm_policy': 'so-zeek-logs', 'managed_by': 'Index Lifecycle Management'}], 'generation': 1, 'status': 'GREEN', 'template': 'so-zeek', 'ilm_policy': 'so-zeek-logs', 'next_generation_managed_by': 'Index Lifecycle Management', 'prefer_ilm': True, 'hidden': False, 'system': False, 'allow_custom_routing': False, 'replicated': False, 'rollover_on_write': False}]}

# %%
zlog = Search(using=conn, index='logs-zeek-so')

conn_log = zlog.query("term", **{"event.dataset": "zeek.conn"})
http_log = zlog.query("term", **{"event.dataset": "zeek.http"})
dns_log = zlog.query("term", **{"event.dataset": "zeek.dns"})
ssl_log = zlog.query("term", **{"event.dataset": "zeek.ssl"})

# %%
conn_12h = conn_log.filter('range', **{'@timestamp': {'gte': 'now-12h', 'lt': 'now'}})
http_12h = http_log.filter('range', **{'@timestamp': {'gte': 'now-12h', 'lt': 'now'}})
dns_12h = dns_log.filter('range', **{'@timestamp': {'gte': 'now-12h', 'lt': 'now'}})
ssl_12h = ssl_log.filter('range', **{'@timestamp': {'gte': 'now-12h', 'lt': 'now'}})

# %%
conn_df = pd.DataFrame()
for hit in conn_12h.scan():
    data = hit.to_dict()['message']
    data = json.loads(data)
    row = pd.DataFrame([data])
    conn_df = pd.concat([conn_df, row], ignore_index=True)

http_df = pd.DataFrame()
for hit in http_12h.scan():
    data = hit.to_dict()['message']
    data = json.loads(data)
    row = pd.DataFrame([data])
    http_df = pd.concat([http_df, row], ignore_index=True)

dns_df = pd.DataFrame()
for hit in dns_12h.scan():
    data = hit.to_dict()['message']
    data = json.loads(data)
    row = pd.DataFrame([data])
    dns_df = pd.concat([dns_df, row], ignore_index=True)

ssl_df = pd.DataFrame()
for hit in ssl_12h.scan():
    data = hit.to_dict()['message']
    data = json.loads(data)
    row = pd.DataFrame([data])
    ssl_df = pd.concat([ssl_df, row], ignore_index=True)

# %%
conn_df
# Out:
#                 ts                 uid id.orig_h  id.orig_p        id.resp_h  \
# 0     1.759308e+09  CNkt0V1GHVBqgODD09  10.0.0.1      34626   172.253.118.94
# 1     1.759309e+09  CdSxiB4g0YycXCiVt3  10.0.0.1      33313  239.255.255.250
# 2     1.759309e+09  CtdMFy1XrFb9tm4Q93  10.0.0.1      59898          8.8.8.8
# 3     1.759309e+09  Cdc5bG2hkz0ILUl65g  10.0.0.2      40686         10.0.0.1
# 4     1.759309e+09   CEFVDWOLr8kT3A9pl  10.0.0.2      58171  239.255.255.250
# ...            ...                 ...       ...        ...              ...
# 3756  1.759294e+09  ClcdGp22MRpQEslMO1  10.0.0.1      40466   172.253.118.95
# 3757  1.759294e+09  CqEjOW3jNXoIzn76Y5  10.0.0.1      60600     142.250.4.97
# 3758  1.759294e+09  CYfG2A2PX0N5nOssD6  10.0.0.1      35245   64.233.170.139
# 3759  1.759294e+09   CzlMBNf5TGqrQ03X9  10.0.0.1      59091    142.251.10.91
# 3760  1.759294e+09   CpUXrw9Ud32xTKMBe  10.0.0.1      37730    64.233.170.91
#
#       id.resp_p proto   service   duration  orig_bytes  ...  local_orig  \
# 0           443   udp  ssl,quic  25.292630      4866.0  ...        True
# 1          1900   udp       NaN   3.003256       688.0  ...        True
# 2            53   udp       dns   0.007364        42.0  ...        True
# 3            80   tcp      http   0.003988      1287.0  ...        True
# 4          1900   udp       NaN   3.004395       692.0  ...        True
# ...         ...   ...       ...        ...         ...  ...         ...
# 3756        443   udp  ssl,quic   0.179452      7399.0  ...        True
# 3757        443   udp  ssl,quic   0.123495      4024.0  ...        True
# 3758        443   udp  ssl,quic   0.217450      6299.0  ...        True
# 3759        443   udp  ssl,quic   0.142350      4219.0  ...        True
# 3760        443   udp  ssl,quic   2.249841     16721.0  ...        True
#
#      local_resp  missed_bytes   history  orig_pkts orig_ip_bytes  resp_pkts  \
# 0         False             0        Dd         12          5202         16
# 1         False             0         D          4           800          0
# 2         False             0        Dd          1            70          1
# 3          True             0  ShADadFf          7          1659          5
# 4         False             0         D          4           804          0
# ...         ...           ...       ...        ...           ...        ...
# 3756      False             0        Dd         12          7735         16
# 3757      False             0        Dd          7          4220         11
# 3758      False             0        Dd         11          6607         11
# 3759      False             0        Dd         10          4499         13
# 3760      False             0        Dd         33         17645         40
#
#       resp_ip_bytes                    community_id  \
# 0              6433  1:hSADkZIdbJ+Jtvlw3lvDUHg9mMg=
# 1                 0  1:eBIXqTomX37qHJCnlZWOKenJe5c=
# 2                86  1:hL3OmvLcdxvtLgNZg/RaMcSzDqI=
# 3               544  1:GC93GoghSZAM6cx4ed7LkEC1+7w=
# 4                 0  1:hmsvyO1YwkuXV6Detnky6We2w5g=
# ...             ...                             ...
# 3756           6689  1:/FEwAdB9yO5ojlKGHC6nyvwNghc=
# 3757           9142  1:4m2UfQjHig/JPVqhWTqT83APogY=
# 3758           5086  1:aXyrk0rgAqmmdOzIWlp9CXbowZ0=
# 3759           7303  1:LM/P7njz+StcKAPho3odbvarUmM=
# 3760          30436  1:MSwcsHSu/T+3bbN1PhNCBsvsFxw=
#
#                                      orig_mac_oui
# 0                                       Dell Inc.
# 1                                       Dell Inc.
# 2                                       Dell Inc.
# 3     LCFC(Hefei) Electronics Technology co., ltd
# 4     LCFC(Hefei) Electronics Technology co., ltd
# ...                                           ...
# 3756                                    Dell Inc.
# 3757                                    Dell Inc.
# 3758                                    Dell Inc.
# 3759                                    Dell Inc.
# 3760                                    Dell Inc.
#
# [3761 rows x 22 columns]

# %%
# group by id.orig_h and id.resp_h
conn_grouped = conn_df.groupby(['id.orig_h', 'id.resp_h'])
conn_grouped
# Loop through each group and convert to DataFrame
for name, group_df in conn_grouped:
    print(f"Group: {name}")
    print(f"Type: {type(group_df)}")  # This is already a DataFrame
    print(group_df)
    print("-" * 50)
# Out:
# Group: ('10.0.0.1', '104.16.100.215')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p       id.resp_h  \
# 1324  1.759303e+09  CqhgAl4HHvbk3Q1Ve4  10.0.0.1      58414  104.16.100.215
# 1450  1.759303e+09  Cw4ANp3fR1xgjTM2f8  10.0.0.1      49298  104.16.100.215
# 1499  1.759303e+09   CMZpGO2tRmOtTf1qh  10.0.0.1      49296  104.16.100.215
#
#       id.resp_p proto service   duration  orig_bytes  ...  local_orig  \
# 1324        443   tcp     ssl   1.505916       993.0  ...        True
# 1450        443   tcp     ssl   1.115085       993.0  ...        True
# 1499        443   tcp     ssl  10.060832       991.0  ...        True
#
#      local_resp  missed_bytes         history  orig_pkts orig_ip_bytes  \
# 1324      False             0        ShADadfF        396         21593
# 1450      False             0       ShADadfFR         15          1769
# 1499      False         23040  ShADadttttgtfF       9307        525859
#
#       resp_pkts  resp_ip_bytes                    community_id  orig_mac_oui
# 1324       6146        9127697  1:J8pdQBMiFiMHbULjfABtRDaiZUM=     Dell Inc.
# 1450         28          28724  1:vx8wR9DSqOX2IxrSZnUkdavbna8=     Dell Inc.
# 1499     187336      278744031  1:ngFZm3qpuOhm6Au5K5kgPTgw1r0=     Dell Inc.
#
# [3 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '104.16.101.215')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p       id.resp_h  \
# 1279  1.759303e+09  CgJPhg2wQEnnctuEU7  10.0.0.1      40144  104.16.101.215
# 1295  1.759303e+09   CxK94ZiQ0zXn0KSz9  10.0.0.1      40128  104.16.101.215
# 1402  1.759303e+09  CI4EUg14gGsUzpOPg6  10.0.0.1      41644  104.16.101.215
#
#       id.resp_p proto service  duration  orig_bytes  ...  local_orig  \
# 1279        443   tcp     ssl  1.012337       993.0  ...        True
# 1295        443   tcp     ssl  0.204152       991.0  ...        True
# 1402        443   tcp     ssl  1.177235       995.0  ...        True
#
#      local_resp  missed_bytes    history  orig_pkts orig_ip_bytes  resp_pkts  \
# 1279      False             0   ShADadfF          9          1469         11
# 1295      False             0   ShADadfF          9          1467         10
# 1402      False             0  ShADdfFaR        891         47323      19176
#
#       resp_ip_bytes                    community_id  orig_mac_oui
# 1279           6564  1:yH/uDoYSbOla3yTexn5gLz6mAk0=     Dell Inc.
# 1295           3471  1:i+WoWYG2XSUYZOa2QaNPsBagG9M=     Dell Inc.
# 1402       28565949  1:NResMtUfU3q5gHFmDFdJL+Scz2Y=     Dell Inc.
#
# [3 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '104.16.80.73')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p     id.resp_h  \
# 1352  1.759302e+09  CwTLIw3hfIg9AAooZe  10.0.0.1      49116  104.16.80.73
# 1896  1.759302e+09  CooAAb2vFfAHWMtmgi  10.0.0.1      60998  104.16.80.73
#
#       id.resp_p proto service    duration  orig_bytes  ...  local_orig  \
# 1352        443   tcp     ssl  390.674368      2538.0  ...        True
# 1896        443   tcp     ssl   86.336985      1835.0  ...        True
#
#      local_resp  missed_bytes   history  orig_pkts orig_ip_bytes  resp_pkts  \
# 1352      False             0  ShADadFf         20          3586         19
# 1896      False             0  ShADadFf         10          2363          9
#
#       resp_ip_bytes                    community_id  orig_mac_oui
# 1352           4905  1:jsqeaClseGlY+WzjuZY5xbfsyzk=     Dell Inc.
# 1896           4273  1:Q0cfwoKBmj8XAdNwWV0X+cjo/VY=     Dell Inc.
#
# [2 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '104.16.98.215')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p      id.resp_h  \
# 1277  1.759303e+09  CP6WOl1KdJL1l8r8T4  10.0.0.1      45652  104.16.98.215
# 1490  1.759303e+09   CHy3ZgmbHfdoLel91  10.0.0.1      45648  104.16.98.215
#
#       id.resp_p proto service  duration  orig_bytes  ...  local_orig  \
# 1277        443   tcp     ssl  1.219672       991.0  ...        True
# 1490        443   tcp     ssl  2.442138       993.0  ...        True
#
#      local_resp  missed_bytes     history  orig_pkts orig_ip_bytes  resp_pkts  \
# 1277      False             0  ShADTadftF         12          1915         11
# 1490      False             0  ShADadttfF        303         18097        615
#
#       resp_ip_bytes                    community_id  orig_mac_oui
# 1277           3530  1:MeqMYbukhnK+qlo0XTNQTYh7mFI=     Dell Inc.
# 1490         904669  1:IYSw8MAvj+bYpBWN9JzRkKI6LSM=     Dell Inc.
#
# [2 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '104.16.99.215')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                uid id.orig_h  id.orig_p      id.resp_h  \
# 1238  1.759303e+09  C6hcGI59lYg1CRpje  10.0.0.1      52388  104.16.99.215
# 1461  1.759303e+09  C7WUb2KD5PpxEM7Q6  10.0.0.1      35622  104.16.99.215
#
#       id.resp_p proto service  duration  orig_bytes  ...  local_orig  \
# 1238        443   tcp     ssl  1.051425       993.0  ...        True
# 1461        443   tcp     ssl  1.138034       991.0  ...        True
#
#      local_resp  missed_bytes   history  orig_pkts orig_ip_bytes  resp_pkts  \
# 1238      False             0  ShADadfF         13          1677         21
# 1461      False             0  ShADadfF          9          1467         11
#
#       resp_ip_bytes                    community_id  orig_mac_oui
# 1238          18841  1:oyRKYLYVbMz9pkYmUpx2aTDx9hk=     Dell Inc.
# 1461           3780  1:KTb4BFmvAUhEw9H4MIlpy9niyqk=     Dell Inc.
#
# [2 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '104.18.32.47')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p     id.resp_h  \
# 543   1.759307e+09  CjV5rt4m1N3jdWTth9  10.0.0.1      49858  104.18.32.47
# 1143  1.759305e+09  Cb0tUm4brb3O1ldfLg  10.0.0.1      45874  104.18.32.47
# 1730  1.759303e+09  CDTHCL1dHXZ6t4nAl1  10.0.0.1      57946  104.18.32.47
# 2030  1.759296e+09  CIFwEf1PCutT65f94k  10.0.0.1      54030  104.18.32.47
# 2702  1.759294e+09  CrgVRK16DVokb18M6i  10.0.0.1      58768  104.18.32.47
# 2725  1.759291e+09  CXxiq024tlXuilZib6  10.0.0.1      38500  104.18.32.47
# 3391  1.759294e+09   CfJZkPQoYmkeqc9m3  10.0.0.1      54678  104.18.32.47
# 3615  1.759294e+09  CYeUOj4VacmWbMdGk3  10.0.0.1      55972  104.18.32.47
#
#       id.resp_p proto service    duration  orig_bytes  ...  local_orig  \
# 543         443   tcp     ssl   54.168561      7424.0  ...        True
# 1143        443   tcp     ssl  245.103887      7434.0  ...        True
# 1730        443   tcp     ssl   95.570648      7328.0  ...        True
# 2030        443   tcp     ssl  320.181543      7424.0  ...        True
# 2702        443   tcp     ssl  400.250450      7401.0  ...        True
# 2725        443   tcp     NaN    0.000832         0.0  ...        True
# 3391        443   tcp     ssl  131.270608      7511.0  ...        True
# 3615        443   tcp     ssl    0.550755      7479.0  ...        True
#
#      local_resp  missed_bytes    history  orig_pkts orig_ip_bytes  resp_pkts  \
# 543       False             0   ShADadFf         17          8316         14
# 1143      False             0  ShADadtFf         21          8546         19
# 1730      False             0     ShADad         15          8116         14
# 2030      False             0    ShADadt         21          8536         20
# 2702      False             0   ShADadfF         23          8617         22
# 2725      False             0     ^dfFAa          2           116          4
# 3391      False             0  ShADadFRr         14          8235         11
# 3615      False             0   ShADadFf         14          8215          8
#
#       resp_ip_bytes                    community_id  orig_mac_oui
# 543            3776  1:8QRpa79VlL1/MOT5gzVMjFxOqC0=     Dell Inc.
# 1143           3979  1:EVxsdhLam3x+PeacqVcpBS0O0c0=     Dell Inc.
# 1730           3762  1:5cFqCXuZjzmlSWIDTvv2qumKpNM=     Dell Inc.
# 2030           4122  1:tcM/6CyKTGzOauAVKgzgyZ3zT0k=     Dell Inc.
# 2702           4108  1:Cje8q9ZcShFKYTELN6d7RoigkOQ=     Dell Inc.
# 2725            247  1:As+VQke/T/i2xBO7sTrwpocujP8=     Dell Inc.
# 3391           3283  1:BeLlXEpCqUV+YNk/b4KnuhZdnAM=     Dell Inc.
# 3615           2336  1:AmY/LVNcf/DrlhSYunVhA9X0Gj4=     Dell Inc.
#
# [8 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '104.18.36.169')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p      id.resp_h  \
# 706   1.759306e+09  Cz7Buz28UCcahKPkHe  10.0.0.1      37471  104.18.36.169
# 707   1.759306e+09   CQcY0rmkDRBHK4DFl  10.0.0.1      32845  104.18.36.169
# 1921  1.759302e+09   CfIZjYg9dwSQeInL4  10.0.0.1      39324  104.18.36.169
# 1927  1.759302e+09  C76sjw4Y73NtSEp7Uk  10.0.0.1      55422  104.18.36.169
#
#       id.resp_p proto   service  duration  orig_bytes  ...  local_orig  \
# 706         443   udp  ssl,quic  0.340377      6454.0  ...        True
# 707         443   udp  ssl,quic  1.403240      9635.0  ...        True
# 1921        443   udp  ssl,quic  0.372136      7639.0  ...        True
# 1927        443   udp  ssl,quic  1.364767      9483.0  ...        True
#
#      local_resp  missed_bytes  history  orig_pkts orig_ip_bytes  resp_pkts  \
# 706       False             0       Dd         11          6762         10
# 707       False             0       Dd         19         10167         16
# 1921      False             0       Dd         15          8059         15
# 1927      False             0       Dd         19         10015         14
#
#       resp_ip_bytes                    community_id  orig_mac_oui
# 706            6015  1:+hn00V9tm1v3POcy2zvlGQxIUZo=     Dell Inc.
# 707            6715  1:N9LvcDCT+OwDOVQghp00+SLdyaE=     Dell Inc.
# 1921           9300  1:6HC/lg+pfyWS5gVDBqkjIQK7wd4=     Dell Inc.
# 1927           5409  1:xfiNFzrbDCMWHhAxdEWjp9A10g0=     Dell Inc.
#
# [4 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '104.18.39.21')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p     id.resp_h  \
# 351   1.759305e+09  CUh6OJ2Hbcj0NP0SE1  10.0.0.1      41116  104.18.39.21
# 1582  1.759303e+09   CnX1KhNVA9tts8s4e  10.0.0.1      35096  104.18.39.21
# 1985  1.759294e+09  CwuDe346HgJnqBkNw5  10.0.0.1      37992  104.18.39.21
# 2032  1.759296e+09  CjQ8kv1Y5StrOCdw83  10.0.0.1      50690  104.18.39.21
# 2871  1.759291e+09  ClzVit32dcymnPhzpd  10.0.0.1      50848  104.18.39.21
# 3713  1.759292e+09   CbHGqRh4eOIJ7jdif  10.0.0.1      53172  104.18.39.21
#
#       id.resp_p proto service     duration  orig_bytes  ...  local_orig  \
# 351         443   tcp     ssl  1985.645802      9990.0  ...        True
# 1582        443   tcp     ssl   121.268238      7784.0  ...        True
# 1985        443   tcp     ssl  2022.875989      9963.0  ...        True
# 2032        443   tcp     ssl   321.351041      7477.0  ...        True
# 2871        443   tcp     NaN  1460.837333      2089.0  ...        True
# 3713        443   tcp     ssl  1983.386960      9510.0  ...        True
#
#      local_resp  missed_bytes    history  orig_pkts orig_ip_bytes  resp_pkts  \
# 351       False             0   ShADadfF        116         16042        212
# 1582      False             0    ShADadt         23          9000         26
# 1985      False             0   ShADadfF        118         16107        216
# 2032      False             0    ShADadt         31          9109         43
# 2871      False             0  ^dDaftAFR         78          6145        152
# 3713      False             0    ShADadr        106         15030        192
#
#       resp_ip_bytes                    community_id  orig_mac_oui
# 351           16256  1:MjTc21lzgbhcrBU4PIZf7xJDMtk=     Dell Inc.
# 1582           4706  1:aZUxIrjxAu5t4gCD6R6s0Rx2ddc=     Dell Inc.
# 1985          16804  1:10ra+xmdDG85AbiADKBLk6sO57M=     Dell Inc.
# 2032           5831  1:mIy8dsgnxg55UiKL8KuY6TVctok=     Dell Inc.
# 2871           9721  1:cxvCghlJWCxQ6lEB3DPMB6gWGxs=     Dell Inc.
# 3713          15215  1:PmLrSnOxWu7lSDLxzki5iOQN9jk=     Dell Inc.
#
# [6 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '104.20.20.192')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                uid id.orig_h  id.orig_p      id.resp_h  \
# 1858  1.759302e+09  CkNOnLB46x1iDd4Pj  10.0.0.1      48840  104.20.20.192
#
#       id.resp_p proto   service  duration  orig_bytes  ...  local_orig  \
# 1858        443   udp  ssl,quic  39.48209      6713.0  ...        True
#
#      local_resp  missed_bytes  history  orig_pkts orig_ip_bytes  resp_pkts  \
# 1858      False             0       Dd         19          7245         22
#
#       resp_ip_bytes                    community_id  orig_mac_oui
# 1858           8533  1:cFpGaTBr3n1p21qiMs1u+4hHafs=     Dell Inc.
#
# [1 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '104.208.16.88')
# Type: <class 'pandas.core.frame.DataFrame'>
#                ts                 uid id.orig_h  id.orig_p      id.resp_h  \
# 962  1.759306e+09  CeuStX2GBELMKuCCKf  10.0.0.1      60438  104.208.16.88
#
#      id.resp_p proto service  duration  orig_bytes  ...  local_orig  \
# 962        443   tcp     ssl  1.330357     10058.0  ...        True
#
#     local_resp  missed_bytes   history  orig_pkts orig_ip_bytes  resp_pkts  \
# 962      False             0  ShADdafF         16         10898         12
#
#      resp_ip_bytes                    community_id  orig_mac_oui
# 962           5789  1:Wy341vOVMkSyLp03PpdJmxol4ek=     Dell Inc.
#
# [1 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '104.208.16.89')
# Type: <class 'pandas.core.frame.DataFrame'>
#               ts                 uid id.orig_h  id.orig_p      id.resp_h  \
# 97  1.759308e+09  CQ7aHA2v7cMmJjTe8b  10.0.0.1      56714  104.208.16.89
#
#     id.resp_p proto service  duration  orig_bytes  ...  local_orig local_resp  \
# 97        443   tcp     ssl  1.252788     10054.0  ...        True      False
#
#     missed_bytes   history  orig_pkts orig_ip_bytes  resp_pkts  resp_ip_bytes  \
# 97             0  ShADdafF         17         10946         13           5841
#
#                       community_id  orig_mac_oui
# 97  1:+dSO/1AHdiwylNI/pD8nDDpRpLM=     Dell Inc.
#
# [1 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '104.208.16.90')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p      id.resp_h  \
# 739   1.759306e+09   CaoTFsomXXWGReeq4  10.0.0.1      33216  104.208.16.90
# 916   1.759304e+09  CRnySA2t7y8TTMnfcl  10.0.0.1      56198  104.208.16.90
# 1116  1.759304e+09  C8EU034XmCnl8NkSxg  10.0.0.1      56206  104.208.16.90
# 1126  1.759304e+09  Cd7GaF2olCKDyCwv4a  10.0.0.1      47730  104.208.16.90
#
#       id.resp_p proto service  duration  orig_bytes  ...  local_orig  \
# 739         443   tcp     ssl  1.179440     10054.0  ...        True
# 916         443   tcp     ssl  1.228936     10054.0  ...        True
# 1116        443   tcp     ssl  0.943390      3245.0  ...        True
# 1126        443   tcp     ssl  1.408213      7053.0  ...        True
#
#      local_resp  missed_bytes   history  orig_pkts orig_ip_bytes  resp_pkts  \
# 739       False             0  ShADdafF         17         10946         13
# 916       False             0  ShADdafF         17         10946         12
# 1116      False             0  ShADdafF         12          3877         10
# 1126      False             0  ShADdafF         15          7841         13
#
#       resp_ip_bytes                    community_id  orig_mac_oui
# 739            5841  1:ISOFaHUzvQiQpltPGE6LgF2fzhc=     Dell Inc.
# 916            5789  1:4oMCdV0nGsJDKNElHlTiTyqFnk0=     Dell Inc.
# 1116           5684  1:zKdn8D8colqpgMMhL32iQcaoxNo=     Dell Inc.
# 1126           5841  1:L5j8PfY7GN3IYShr0I0isMXHESU=     Dell Inc.
#
# [4 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '104.208.16.95')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p      id.resp_h  \
# 906   1.759306e+09  CokVDB1JRVj6fyPhk1  10.0.0.1      37736  104.208.16.95
# 1359  1.759303e+09   CTISO2PcQcmviWq11  10.0.0.1      57692  104.208.16.95
# 2273  1.759294e+09  CWqWdm3TuNbed6cD68  10.0.0.1      57422  104.208.16.95
# 3279  1.759294e+09  CKeZXd4iraNFmYsNrl  10.0.0.1      57438  104.208.16.95
#
#       id.resp_p proto service    duration  orig_bytes  ...  local_orig  \
# 906         443   tcp     ssl    1.125658     10054.0  ...        True
# 1359        443   tcp     ssl  178.987416     45821.0  ...        True
# 2273        443   tcp     ssl  403.857542     31101.0  ...        True
# 3279        443   tcp     ssl  107.890048      2596.0  ...        True
#
#      local_resp  missed_bytes    history  orig_pkts orig_ip_bytes  resp_pkts  \
# 906       False             0  ShADdatfF         17         10946         13
# 1359      False             0  ShADadtFf         74         49677         51
# 2273      False             0   ShADadtF         59         34177         39
# 3279      False             0   ShADadFr         12          3228         13
#
#       resp_ip_bytes                    community_id  orig_mac_oui
# 906            5841  1:wZdEd4wbfCZ33sSd8+fpEexY638=     Dell Inc.
# 1359          10546  1:r4yfKwBjCd/U/O28xdfyqSZb44E=     Dell Inc.
# 2273           9546  1:fQ2CGNsBXhiIhTKc2xiWqzyLYYw=     Dell Inc.
# 3279           7301  1:4eRJrYAzmalFJtk2e5V4IuHV3fg=     Dell Inc.
#
# [4 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '104.21.10.81')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p     id.resp_h  \
# 1859  1.759302e+09  CUjTAt3VX10vXEb6h3  10.0.0.1      43844  104.21.10.81
#
#       id.resp_p proto   service  duration  orig_bytes  ...  local_orig  \
# 1859        443   udp  ssl,quic  0.589952      4455.0  ...        True
#
#      local_resp  missed_bytes  history  orig_pkts orig_ip_bytes  resp_pkts  \
# 1859      False             0       Dd         11          4763         12
#
#       resp_ip_bytes                    community_id  orig_mac_oui
# 1859           6770  1:O83un1hjXf1up7OkYne/us7djA4=     Dell Inc.
#
# [1 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '104.21.80.27')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p     id.resp_h  \
# 2328  1.759294e+09  C2oVhR2uWIOCB37BH5  10.0.0.1      39380  104.21.80.27
#
#       id.resp_p proto   service   duration  orig_bytes  ...  local_orig  \
# 2328        443   udp  ssl,quic  23.995863      4728.0  ...        True
#
#      local_resp  missed_bytes  history  orig_pkts orig_ip_bytes  resp_pkts  \
# 2328      False             0       Dd         13          5092         12
#
#       resp_ip_bytes                    community_id  orig_mac_oui
# 2328           7379  1:JHC9wF3QdXacRUi8EUygXfl6ZWw=     Dell Inc.
#
# [1 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '104.212.68.135')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                uid id.orig_h  id.orig_p       id.resp_h  \
# 3513  1.759293e+09  CBFyQsqwcB2yMEvzj  10.0.0.1      58348  104.212.68.135
#
#       id.resp_p proto service   duration  orig_bytes  ...  local_orig  \
# 3513        443   tcp     ssl  90.362731      2816.0  ...        True
#
#      local_resp  missed_bytes     history  orig_pkts orig_ip_bytes  resp_pkts  \
# 3513      False             0  ShADadftFR         21          3916         24
#
#       resp_ip_bytes                    community_id  orig_mac_oui
# 3513          15848  1:iN0LEIeqRyKftUK8YtFt34Q9SSU=     Dell Inc.
#
# [1 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '104.26.4.190')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p     id.resp_h  \
# 1358  1.759302e+09  C58HeE4AtWJ5WOeXv6  10.0.0.1      55608  104.26.4.190
# 1873  1.759302e+09  Cq3Dix1uKfOhW3yEV3  10.0.0.1      55616  104.26.4.190
# 1891  1.759302e+09  CFEN0M3a1vgNqpp9q9  10.0.0.1      60083  104.26.4.190
#
#       id.resp_p proto   service    duration  orig_bytes  ...  local_orig  \
# 1358        443   tcp       ssl  391.646275      7947.0  ...        True
# 1873        443   tcp       ssl   62.502712      1899.0  ...        True
# 1891        443   udp  ssl,quic   66.129586    253739.0  ...        True
#
#      local_resp  missed_bytes   history  orig_pkts orig_ip_bytes  resp_pkts  \
# 1358      False             0  ShADadFf         96         12947        213
# 1873      False             0  ShADadFf         11          2479          9
# 1891      False             0        Dd       1811        304447       3475
#
#       resp_ip_bytes                    community_id  orig_mac_oui
# 1358         240834  1:IqGyrV2+tvPjVhMh7xh5Qg/Z3g4=     Dell Inc.
# 1873           4298  1:cUOnxXna+gBo5FRhwleV7gsuCok=     Dell Inc.
# 1891        3855407  1:XvKwQ0Rp3PI+Vi/NU8yZ12Xqtz4=     Dell Inc.
#
# [3 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '104.46.162.227')
# Type: <class 'pandas.core.frame.DataFrame'>
#                ts                 uid id.orig_h  id.orig_p       id.resp_h  \
# 624  1.759306e+09  CyAzr64o6VA0VCxg17  10.0.0.1      48780  104.46.162.227
#
#      id.resp_p proto service  duration  orig_bytes  ...  local_orig  \
# 624        443   tcp     ssl   1.12081     10054.0  ...        True
#
#     local_resp  missed_bytes   history  orig_pkts orig_ip_bytes  resp_pkts  \
# 624      False             0  ShADdafF         17         10946         14
#
#      resp_ip_bytes                    community_id  orig_mac_oui
# 624           5894  1:HfHaMG5le9wAgdsKozgw0GKQQ04=     Dell Inc.
#
# [1 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '107.178.255.183')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p        id.resp_h  \
# 1289  1.759303e+09  C4ldMe2n4j88TGzIub  10.0.0.1      55442  107.178.255.183
# 1348  1.759303e+09  CsqT9n3ZY0EUUJSild  10.0.0.1      49879  107.178.255.183
# 1356  1.759303e+09   COXj3LteGQpJVEsh4  10.0.0.1      58594  107.178.255.183
# 1989  1.759303e+09  Cthnqk2KRCh4To7JH8  10.0.0.1      35385  107.178.255.183
#
#       id.resp_p proto   service  duration  orig_bytes  ...  local_orig  \
# 1289        443   udp  ssl,quic  0.121828      2736.0  ...        True
# 1348        443   udp  ssl,quic  0.094747      2736.0  ...        True
# 1356        443   tcp       ssl  2.649534      3793.0  ...        True
# 1989        443   udp  ssl,quic  0.040017      4158.0  ...        True
#
#      local_resp  missed_bytes   history  orig_pkts orig_ip_bytes  resp_pkts  \
# 1289      False             0        Dd          5          2876          9
# 1348      False             0        Dd          5          2876          9
# 1356      False             0  ShADadFf         15          4581         13
# 1989      False             0        Dd          6          4326          8
#
#       resp_ip_bytes                    community_id  orig_mac_oui
# 1289           6430  1:NRAQWp0JDVGQbBB0YkgsMw8z8og=     Dell Inc.
# 1348           6432  1:iOo2ARaHyliK3v1AHVq4FH2sDHo=     Dell Inc.
# 1356           5846  1:YZCEXQ0WYRF3IFSpip2bSEkSuZ4=     Dell Inc.
# 1989           6966  1:tDwNxhznyrFI51FO1MehcH0uha4=     Dell Inc.
#
# [4 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '107.23.171.179')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p       id.resp_h  \
# 1318  1.759303e+09  C1o5kc3jqyOHAUa741  10.0.0.1      56382  107.23.171.179
# 1456  1.759303e+09   C4YnU4PeRoOteSJ9a  10.0.0.1      56376  107.23.171.179
#
#       id.resp_p proto service  duration  orig_bytes  ...  local_orig  \
# 1318        443   tcp     NaN  1.291294         0.0  ...        True
# 1456        443   tcp     NaN  0.278053         0.0  ...        True
#
#      local_resp  missed_bytes  history  orig_pkts orig_ip_bytes  resp_pkts  \
# 1318      False             0      ShR          2           100          1
# 1456      False             0      ShR          2           100          1
#
#       resp_ip_bytes                    community_id  orig_mac_oui
# 1318             60  1:3AYZrNt3k1vaz1y34rcJTumyqyo=     Dell Inc.
# 1456             60  1:uh1KtUsyfUXIsNL1WPeTD3hwfzY=     Dell Inc.
#
# [2 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '113.161.78.134')
# Type: <class 'pandas.core.frame.DataFrame'>
#                ts                 uid id.orig_h  id.orig_p       id.resp_h  \
# 531  1.759307e+09  CtMBKk3viVbuzoHYra  10.0.0.1      51722  113.161.78.134
#
#      id.resp_p proto service   duration  orig_bytes  ...  local_orig  \
# 531         80   tcp    http  10.136692      9266.0  ...        True
#
#     local_resp  missed_bytes     history  orig_pkts orig_ip_bytes  resp_pkts  \
# 531      False             0  ShADadttFf       2919        161962       5384
#
#      resp_ip_bytes                    community_id  orig_mac_oui
# 531        8007915  1:lHY80gE6fX+eQzw0nlqkkRg9msg=     Dell Inc.
#
# [1 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '114.232.92.35')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p      id.resp_h  \
# 3249  1.759294e+09   CxS2ohgPFb82vqdsd  10.0.0.1      48784  114.232.92.35
# 3557  1.759293e+09   CKrJhescYgFzmxDJ4  10.0.0.1      48794  114.232.92.35
# 3559  1.759293e+09  CxSHoF10LajYuCflqi  10.0.0.1      48784  114.232.92.35
# 3572  1.759294e+09  Cu4nYV2AY8VK4NYchj  10.0.0.1      48784  114.232.92.35
# 3582  1.759294e+09  CnG5OM2I4WjyulCWnb  10.0.0.1      48784  114.232.92.35
#
#       id.resp_p proto service    duration  orig_bytes  ...  local_orig  \
# 3249        443   tcp     NaN         NaN         NaN  ...        True
# 3557        443   tcp     ssl  294.044934      2842.0  ...        True
# 3559        443   tcp     ssl  294.294975      1819.0  ...        True
# 3572        443   tcp     NaN         NaN         NaN  ...        True
# 3582        443   tcp     NaN         NaN         NaN  ...        True
#
#      local_resp  missed_bytes      history  orig_pkts orig_ip_bytes  \
# 3249      False             0            F          1            40
# 3557      False             0  ShADTadttfR        137         10245
# 3559      False             0   ShADTadtfF         32          9314
# 3572      False             0            F          1            40
# 3582      False             0            F          1            40
#
#       resp_pkts  resp_ip_bytes                    community_id  orig_mac_oui
# 3249          0              0  1:48HXpfHnEIZ/zgrrn13m2Owj6Mk=     Dell Inc.
# 3557        287         392151  1:raPUNnQi1vB2J9VBMKDH4kk0pkY=     Dell Inc.
# 3559         25          15802  1:48HXpfHnEIZ/zgrrn13m2Owj6Mk=     Dell Inc.
# 3572          0              0  1:48HXpfHnEIZ/zgrrn13m2Owj6Mk=     Dell Inc.
# 3582          0              0  1:48HXpfHnEIZ/zgrrn13m2Owj6Mk=     Dell Inc.
#
# [5 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '115.165.161.155')
# Type: <class 'pandas.core.frame.DataFrame'>
#                ts                uid id.orig_h  id.orig_p        id.resp_h  \
# 589  1.759307e+09  CchH9gutQL6KLjndc  10.0.0.1      54934  115.165.161.155
#
#      id.resp_p proto service   duration  orig_bytes  ...  local_orig  \
# 589         80   tcp    http  22.111926      8851.0  ...        True
#
#     local_resp  missed_bytes     history  orig_pkts orig_ip_bytes  resp_pkts  \
# 589      False             0  ShADadttFf      83195       4339991     167855
#
#      resp_ip_bytes                    community_id  orig_mac_oui
# 589      250398253  1:pDEmD52clWjElI3/4TxP4kxh9HM=     Dell Inc.
#
# [1 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '116.108.196.111')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p        id.resp_h  \
# 381   1.759306e+09   CgpKNo1o14FHBg2tO  10.0.0.1      50762  116.108.196.111
# 780   1.759305e+09  C5L1b41FRAN24C2jf7  10.0.0.1      45282  116.108.196.111
# 1159  1.759304e+09  CDI1oz30juWbRuUtz6  10.0.0.1      60234  116.108.196.111
# 1716  1.759302e+09  CIaKhC4G3GNrSLvLfg  10.0.0.1      47737  116.108.196.111
# 2709  1.759294e+09  C3VDeE4KFpDqcBDsJ3  10.0.0.1      56972  116.108.196.111
# 2747  1.759291e+09  CxuT5913phc8hhuM4a  10.0.0.1      52626  116.108.196.111
# 2844  1.759292e+09  CYV8r83ywbcDipNFWk  10.0.0.1      50904  116.108.196.111
# 2911  1.759292e+09   CiBVjXofdYkaPec42  10.0.0.1      56376  116.108.196.111
# 3028  1.759291e+09  CPelRs4SINlqtJsRp9  10.0.0.1      55419  116.108.196.111
# 3237  1.759293e+09  CktGA41LbU34Kmjlxk  10.0.0.1      41517  116.108.196.111
# 3520  1.759293e+09  CD3yAf373CS1TaegGg  10.0.0.1      33267  116.108.196.111
#
#       id.resp_p proto         service     duration  orig_bytes  ...  \
# 381         443   udp        ssl,quic   557.407405    658235.0  ...
# 780         443   udp        ssl,quic    60.678057    102464.0  ...
# 1159        443   udp  ayiya,ssl,quic   842.037619   1257729.0  ...
# 1716        443   udp        ssl,quic  1344.653385   1690973.0  ...
# 2709        443   udp        ssl,quic   420.124927    524718.0  ...
# 2747        443   udp             NaN   241.018767    312902.0  ...
# 2844        443   udp  ayiya,ssl,quic   260.497833    324136.0  ...
# 2911        443   udp        ssl,quic   347.125625    444361.0  ...
# 3028        443   udp  ayiya,ssl,quic   414.379151    521326.0  ...
# 3237        443   udp  ayiya,ssl,quic   145.336125    199006.0  ...
# 3520        443   udp        ssl,quic   490.928057    724364.0  ...
#
#       local_orig local_resp  missed_bytes  history  orig_pkts orig_ip_bytes  \
# 381         True      False             0       Dd       3260        749515
# 780         True      False             0       Dd       1106        133432
# 1159        True      False             0       Dd      11350       1575529
# 1716        True      False             0       Dd       8089       1917465
# 2709        True      False             0       Dd       3052        610174
# 2747        True      False             0       Dd       1867        365178
# 2844        True      False             0       Dd       2108        383160
# 2911        True      False             0       Dd       2690        519681
# 3028        True      False             0       Dd       3154        609638
# 3237        True      False             0       Dd        957        225802
# 3520        True      False             0       Dd       6248        899308
#
#       resp_pkts  resp_ip_bytes                    community_id  orig_mac_oui
# 381       18701       23193721  1:IsVbSdwvF0jtpdongIHr0R9uV5o=     Dell Inc.
# 780        7690        9731473  1:brc+P/UxO+TfLK2V5KZZ3Agh2Co=     Dell Inc.
# 1159      78235       98827443  1:CKqOQ3VJm/5aJWwpFQPYMHOpFpM=     Dell Inc.
# 1716      45632       56517799  1:AZJwtjg4zZq5kd7GcV6Pkgfu5EA=     Dell Inc.
# 2709      18867       23542132  1:njgUgS0DUUxZg18bsE1wYgHkat4=     Dell Inc.
# 2747      11297       14095292  1:xLZ+3BdUCoj4PNMK8inWzqrYDCI=     Dell Inc.
# 2844      12872       16117277  1:KM0ns6xZB8NibgfMnbNUXD3hrcs=     Dell Inc.
# 2911      16703       20878569  1:3ms5/p5UZUO4OP7eXi+vWYLyAcQ=     Dell Inc.
# 3028      19184       23942813  1:g2Tkrk4MiHBy0CwhvZUOdrPumCg=     Dell Inc.
# 3237       5302        6560010  1:+LeNaudMijKVq5C/fwqPBUL1oSc=     Dell Inc.
# 3520      42805       54006644  1:yaJ+sQhYumiIur5SM4RDV31gMXo=     Dell Inc.
#
# [11 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '117.0.212.143')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p      id.resp_h  \
# 3736  1.759294e+09  CdLWlJ3aXKEt0vX9C3  10.0.0.1      48128  117.0.212.143
#
#       id.resp_p proto   service  duration  orig_bytes  ...  local_orig  \
# 3736        443   udp  ssl,quic  0.016143      4871.0  ...        True
#
#      local_resp  missed_bytes  history  orig_pkts orig_ip_bytes  resp_pkts  \
# 3736      False             0       Dd         10          5151         13
#
#       resp_ip_bytes                    community_id  orig_mac_oui
# 3736           7408  1:UoS/BmgMCJ7StP1bL/PbZoJd538=     Dell Inc.
#
# [1 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '125.234.51.43')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p      id.resp_h  \
# 2638  1.759294e+09  CkOLHb2igVbXaWL1ve  10.0.0.1      51240  125.234.51.43
# 2640  1.759294e+09   Czz9Xaw6PT568pU4h  10.0.0.1      51214  125.234.51.43
# 2643  1.759294e+09  CfI7Z03BXKXtIUOJHl  10.0.0.1      51270  125.234.51.43
# 3262  1.759293e+09  Cd7BX62FX5E3s8ZJb4  10.0.0.1      39242  125.234.51.43
# 3264  1.759293e+09  CCJFBZ2VPHfJyCltvi  10.0.0.1      39212  125.234.51.43
# 3589  1.759293e+09   CxrsdTs0Lfe0QbUmk  10.0.0.1      39226  125.234.51.43
# 3667  1.759294e+09   CmlmrEFjhy8AqUFM1  10.0.0.1      51256  125.234.51.43
# 3673  1.759294e+09   CO6O47cecCCWANyCg  10.0.0.1      51226  125.234.51.43
#
#       id.resp_p proto service    duration  orig_bytes  ...  local_orig  \
# 2638        443   tcp     ssl   25.044360      2543.0  ...        True
# 2640        443   tcp     ssl   25.060577      2589.0  ...        True
# 2643        443   tcp     ssl   24.852060      2589.0  ...        True
# 3262        443   tcp     ssl  415.040660      3442.0  ...        True
# 3264        443   tcp     ssl  415.095939      3882.0  ...        True
# 3589        443   tcp     ssl  415.091727      3275.0  ...        True
# 3667        443   tcp     ssl   24.858630      2549.0  ...        True
# 3673        443   tcp     ssl   25.045639      4491.0  ...        True
#
#      local_resp  missed_bytes        history  orig_pkts orig_ip_bytes  \
# 2638      False             0     ShADadFftR         13          3203
# 2640      False             0     ShADadFftR         13          3249
# 2643      False             0      ShADadFfR         13          3249
# 3262      False             0  ShADadttttFfR       6060        331778
# 3264      False             0  ShADadttttFfR       1913        109194
# 3589      False             0     ShADadFftR       1800         96859
# 3667      False             0     ShADadFftR         13          3209
# 3673      False             0      ShADadFfR         19          5463
#
#       resp_pkts  resp_ip_bytes                    community_id  orig_mac_oui
# 2638         14           8907  1:7vCwZZM/PzB3JIF7LyZHmP2hJ+Q=     Dell Inc.
# 2640         13           5669  1:tOwg7i1mcw3xYh1iKhYLL2q4dyI=     Dell Inc.
# 2643         15           9197  1:GtP7nknZIGw98sU/9oY568s0rI8=     Dell Inc.
# 3262      84582      124660247  1:0CMwWbvfD+hvYo/KFzuufcdqqlQ=     Dell Inc.
# 3264      22716       33486277  1:fQektarZn22faSEfnEFKybeNLdM=     Dell Inc.
# 3589      12884       19148306  1:VIeZc5mLZE06QBnZWSDZWLK7D9A=     Dell Inc.
# 3667         17          13578  1:Nu9tmAuAS11m/TzGXXB+7RyqC14=     Dell Inc.
# 3673         60          65943  1:AJ4EVbJPOaUccff7UdmdEoC3b/Q=     Dell Inc.
#
# [8 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '125.234.51.48')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p      id.resp_h  \
# 3265  1.759293e+09  CCzxHA4by8WlFfz3ma  10.0.0.1      49852  125.234.51.48
# 3590  1.759293e+09  CR8uV51sABeVg5oTy4  10.0.0.1      49844  125.234.51.48
# 3670  1.759294e+09   CY68SC2OlQbppxnl6  10.0.0.1      48698  125.234.51.48
#
#       id.resp_p proto service    duration  orig_bytes  ...  local_orig  \
# 3265        443   tcp     ssl  415.093117      3439.0  ...        True
# 3590        443   tcp     ssl  415.093122      3383.0  ...        True
# 3670        443   tcp     ssl   22.736919      3321.0  ...        True
#
#      local_resp  missed_bytes     history  orig_pkts orig_ip_bytes  resp_pkts  \
# 3265      False             0  ShADadFftR        134         10391       1647
# 3590      False             0  ShADadFftR         69          6955        649
# 3670      False             0   ShADadFfR         55          6165        488
#
#       resp_ip_bytes                    community_id  orig_mac_oui
# 3265        2395122  1:Xk2oFDz1qA1JVoY+BijzbGFcgEk=     Dell Inc.
# 3590         937939  1:Jwkv6JqZTN5SlCBrO5pVi2eIrbo=     Dell Inc.
# 3670         703584  1:jgO8MQxPL2HlStMTzigT7Xd0VEg=     Dell Inc.
#
# [3 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '13.107.213.73')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p      id.resp_h  \
# 169   1.759307e+09   Cg7uDQ64EAO30qJ3b  10.0.0.1      46624  13.107.213.73
# 338   1.759308e+09  CFPhi61cZFiAMmjsdc  10.0.0.1      40934  13.107.213.73
# 413   1.759306e+09   CUOGds1hZdy3EGBUB  10.0.0.1      58468  13.107.213.73
# 529   1.759307e+09  CsfDIu4kuLigePEd53  10.0.0.1      48736  13.107.213.73
# 692   1.759306e+09  CtG5Fa2ucqEUJHQUec  10.0.0.1      33054  13.107.213.73
# 821   1.759307e+09  CVfVbF16uSaZzVTJJd  10.0.0.1      52820  13.107.213.73
# 1074  1.759304e+09  Cm6MKy3kvIyrckbz97  10.0.0.1      49762  13.107.213.73
# 1176  1.759304e+09  C5uDAz10JQ90LhJLbg  10.0.0.1      46824  13.107.213.73
#
#       id.resp_p proto service   duration  orig_bytes  ...  local_orig  \
# 169         443   tcp     ssl  90.114956      3404.0  ...        True
# 338         443   tcp     ssl  90.165100      2926.0  ...        True
# 413         443   tcp     ssl  90.178190      3404.0  ...        True
# 529         443   tcp     ssl  90.167165      2926.0  ...        True
# 692         443   tcp     ssl  90.235463      2734.0  ...        True
# 821         443   tcp     ssl  90.218497      3532.0  ...        True
# 1074        443   tcp     ssl  90.125056      2880.0  ...        True
# 1176        443   tcp     ssl  90.160599      3468.0  ...        True
#
#      local_resp  missed_bytes     history  orig_pkts orig_ip_bytes  resp_pkts  \
# 169       False             0    ShADadfF         34          5180         54
# 338       False             0    ShADadfF         37          4858         61
# 413       False             0   ShADadfFt         35          5244         56
# 529       False             0    ShADadfF         38          4910         61
# 692       False             0   ShADadftF         41          4910         62
# 821       False             0    ShADadfF         34          5320         57
# 1074      False             0  ShADadftFR         21          3992         26
# 1176      False             0    ShADadfR         35          5296         54
#
#       resp_ip_bytes                    community_id  orig_mac_oui
# 169           63920  1:uqCXNxR37Ij3qgEHd6EdI8/TiEo=     Dell Inc.
# 338           71573  1:EGJig/qJ2xvaXmHkvE0IKzdyv5I=     Dell Inc.
# 413           64070  1:Xfzi7jlzw2Gqi6UND4wZf+pf3+4=     Dell Inc.
# 529           71572  1:ywWRPMQGr3wTHRdbRwi44ugYbww=     Dell Inc.
# 692           71709  1:cjc3Zgi+KcFIhQ0lg6POHaKD+/Y=     Dell Inc.
# 821           64097  1:B4Q3DdHB9pLPIjdo3P8duOoeWWw=     Dell Inc.
# 1074          15951  1:/+2V0suuxLVcMppfBy4h5F60GSs=     Dell Inc.
# 1176          63942  1:YM6wcUrzE5wgWsTj7LIOcV5cQV8=     Dell Inc.
#
# [8 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '13.107.226.59')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p      id.resp_h  \
# 3254  1.759294e+09  Cc3Z0r1CiHrp4WpFSl  10.0.0.1      48998  13.107.226.59
# 3514  1.759293e+09  CSciRt3OjadCzam4Q8  10.0.0.1      37326  13.107.226.59
#
#       id.resp_p proto service   duration  orig_bytes  ...  local_orig  \
# 3254        443   tcp     ssl  90.268672      3468.0  ...        True
# 3514        443   tcp     ssl  90.193198      3021.0  ...        True
#
#      local_resp  missed_bytes     history  orig_pkts orig_ip_bytes  resp_pkts  \
# 3254      False             0    ShADadfF         37          5400         61
# 3514      False             0  ShADdaftFR         19          4017         23
#
#       resp_ip_bytes                    community_id  orig_mac_oui
# 3254          71572  1:cQTMzdtjVKKWO3titPi+m4z2IdU=     Dell Inc.
# 3514          11130  1:kFUrzG188ZrqZV1nzgOcvmEZuNk=     Dell Inc.
#
# [2 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '13.107.246.59')
# Type: <class 'pandas.core.frame.DataFrame'>
#                ts                 uid id.orig_h  id.orig_p      id.resp_h  \
# 471  1.759307e+09  CgFuZ61iz3ZywdzVff  10.0.0.1      49644  13.107.246.59
#
#      id.resp_p proto service  duration  orig_bytes  ...  local_orig  \
# 471        443   tcp     ssl  90.04359      3404.0  ...        True
#
#     local_resp  missed_bytes    history  orig_pkts orig_ip_bytes  resp_pkts  \
# 471      False             0  ShADadftF         36          5296         53
#
#      resp_ip_bytes                    community_id  orig_mac_oui
# 471          63867  1:wua3XVcQWFt16LKQxRr5Rp7YQck=     Dell Inc.
#
# [1 rows x 22 columns]
# --------------------------------------------------
# Group: ('10.0.0.1', '13.107.246.73')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid id.orig_h  id.orig_p      id.resp_h  \
# 37    1.759308e+09  CtGRL54nVFSpPl3oZ9  10.0.0.1      52118  13.107.246.73
# 143   1.759308e+09  CRypWs4euAQdLg8NIf  10.0.0.1      41128  13.107.246.73
# 636   1.759306e+09  C3URG24iYrxGvQmvta  10.0.0.1      40206  13.107.246.73
# 840   1.759305e+09   Cva68E20nBaRSVUm4  10.0.0.1      41700  13.107.246.73
# 1028  1.759305e+09  CX4cEe1ic8lwpFyAnk  10.0.0.1      38558  13.107.246.73
# 1122  1.759305e+09  Ct48cJ3k3I8Su1ekwl  10.0.0.1      56372  13.107.246.73
# 1218  1.759305e+09  C2XsBc1zT4uisXfBT8  10.0.0.1      41714  13.107.246.73
# 1344  1.759303e+09  CCe3vE1TpWWhKKm912  10.0.0.1      56916  13.107.246.73
# 1580  1.759303e+09  CRMUfu2v6DNEP36gog  10.0.0.1      33788  13.107.246.73
# 1747  1.759302e+09   CwrSu1BSYdO6MQVtd  10.0.0.1      59748  13.107.246.73
# 1852  1.759302e+09  C79PKi1tkITcpXKBzj  10.0.0.1      53318  13.107.246.73
# 1973  1.759296e+09   CMPZnOSYDYq1HE3Pi  10.0.0.1      36542  13.107.246.73
# 2013  1.759296e+09  C05HAR3owkRrni0WCj  10.0.0.1      34304  13.107.246.73
# 2189  1.759302e+09  CdiaRs24boGQQKxI87  10.0.0.1      34378  13.107.246.73
# 2190  1.759302e+09  CQTOiF4ouqKxnwwFJi  10.0.0.1      34364  13.107.246.73
# 2408  1.759295e+09   CkxvqurLAQQnaK0Cg  10.0.0.1      54676  13.107.246.73
# 2427  1.759295e+09  C26n6K2pmhKi0hD7Qb  10.0.0.1      56156  13.107.246.73
# 2444  1.759295e+09  Ck55Yv2uEUyFrXmD1g  10.0.0.1      50830  13.107.246.73
# 2458  1.759296e+09  Cq6o6s239fPT8VIB4g  10.0.0.1      52336  13.107.246.73
# 2646  1.759294e+09  CpUrtx4OXde4PJavab  10.0.0.1      34552  13.107.246.73
# 2707  1.759295e+09   CW6tzjXs2NWuzCoNj  10.0.0.1      51642  13.107.246.73
# 3518  1.759294e+09  Ce0Yyz4mJNgy4Kx5ed  10.0.0.1      42004  13.107.246.73
# 3579  1.759294e+09  C3LF2m2OMFoMTfNETd  10.0.0.1      36936  13.107.246.73
#
#       id.resp_p proto service    duration  orig_bytes  ...  local_orig  \
# 37          443   tcp     ssl   90.112657      3404.0  ...        True
# 143         443   tcp     ssl   90.206078      3404.0  ...        True
# 636         443   tcp     ssl   90.241302      3340.0  ...        True
# 840         443   tcp     ssl   90.232026      3534.0  ...        True
# 1028        443   tcp     ssl   90.348521      3340.0  ...        True
# 1122        443   tcp     ssl   90.224678      2734.0  ...        True
# 1218        443   tcp     ssl   90.177170      3340.0  ...        True
# 1344        443   tcp     ssl  101.758822      3666.0  ...        True
# 1580        443   tcp     ssl   46.604938      3340.0  ...        True
# 1747        443   tcp     ssl   90.237759      3468.0  ...        True
# 1852        443   tcp     ssl   90.223305      2862.0  ...        True
# 1973        443   tcp     ssl   90.099820      3532.0  ...        True
# 2013        443   tcp     ssl   90.134828      2798.0  ...        True
# 2189        443   tcp     ssl   90.124606      2992.0  ...        True
# 2190        443   tcp     ssl   90.209508      3532.0  ...        True
# 2408        443   tcp     ssl   90.224676      3532.0  ...        True
# 2427        443   tcp     ssl   90.323583      2734.0  ...        True
# 2444        443   tcp     ssl   90.166395      3340.0  ...        True
# 2458        443   tcp     ssl   90.272525      3340.0  ...        True
# 2646        443   tcp     ssl   50.479853      2752.0  ...        True
# 2707        443   tcp     ssl   90.205122      2880.0  ...        True
# 3518        443   tcp     ssl   84.242835      3340.0  ...        True
# 3579        443   tcp     ssl   39.998302      2880.0  ...        True
#
#      local_resp  missed_bytes     history  orig_pkts orig_ip_bytes  resp_pkts  \
# 37        False             0   ShADadftF         37          5360         55
# 143       False             0   ShADadftF         38          5424         56
# 636       False             0   ShADadtfF         35          5180         55
# 840       False             0  ShADadftFR         18          4502         16
# 1028      False             0   ShADadftF         38          5372         59
# 1122      False             0   ShADadftF         37          4678         62
# 1218      False             0   ShADadftF         38          5360         56
# 1344      False             0   ShADadfFR         40          5742         65
# 1580      False             0      ShADad         33          5064         52
# 1747      False             0  ShADadftFR         34          5244         56
# 1852      False             0   ShADadftF         38          4858         64
# 1973      False             0    ShADadfF         34          5308         54
# 2013      False             0   ShADadfFR         37          4718         64
# 2189      False             0  ShADadftFR         19          3988         22
# 2190      False             0   ShADadftF         32          5216         55
# 2408      False             0   ShADadfFR         35          5360         58
# 2427      False             0   ShADadftF         42          4974         66
# 2444      False             0    ShADadfF         36          5232         56
# 2458      False             0  ShADadftFR         36          5220         57
# 2646      False             0   ShADTadFf         21          4185         24
# 2707      False             0   ShADadftF         21          4016         26
# 3518      False             0    ShADadFf         35          5168         59
# 3579      False             0    ShADadFf         18          3824         21
#
# ...
# Group: ('fe80::f2a4:8a20:4403:72b7', 'ff02::16')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid                  id.orig_h  id.orig_p  \
# 1663  1.759304e+09  C9dBvh1r2dJzKYw0G3  fe80::f2a4:8a20:4403:72b7        143
# 2151  1.759302e+09  C3nMyu21PTKMQablPk  fe80::f2a4:8a20:4403:72b7        143
# 3646  1.759294e+09  CJ7FV730DS50faLKwi  fe80::f2a4:8a20:4403:72b7        143
# 3714  1.759294e+09  CRJ6EI2xKmXKlt17rl  fe80::f2a4:8a20:4403:72b7        143
#
#      id.resp_h  id.resp_p proto service  duration  orig_bytes  ...  \
# 1663  ff02::16          0  icmp     NaN  0.288405        80.0  ...
# 2151  ff02::16          0  icmp     NaN  0.391895        80.0  ...
# 3646  ff02::16          0  icmp     NaN  0.279652        80.0  ...
# 3714  ff02::16          0  icmp     NaN  0.704254        80.0  ...
#
#       local_orig local_resp  missed_bytes  history  orig_pkts orig_ip_bytes  \
# 1663        True      False             0      NaN          2           192
# 2151        True      False             0      NaN          2           192
# 3646        True      False             0      NaN          2           192
# 3714        True      False             0      NaN          2           192
#
#       resp_pkts  resp_ip_bytes                    community_id  orig_mac_oui
# 1663          0              0  1:LGccA9mGnnHgJ4AJ5mbvcvY9PWg=     Dell Inc.
# 2151          0              0  1:LGccA9mGnnHgJ4AJ5mbvcvY9PWg=     Dell Inc.
# 3646          0              0  1:LGccA9mGnnHgJ4AJ5mbvcvY9PWg=     Dell Inc.
# 3714          0              0  1:LGccA9mGnnHgJ4AJ5mbvcvY9PWg=     Dell Inc.
#
# [4 rows x 22 columns]
# --------------------------------------------------
# Group: ('fe80::f2a4:8a20:4403:72b7', 'ff02::2')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid                  id.orig_h  id.orig_p  \
# 301   1.759308e+09   C9PNeZYaOA775Itp1  fe80::f2a4:8a20:4403:72b7        133
# 716   1.759306e+09  CxOxL54QJOK7tny3Se  fe80::f2a4:8a20:4403:72b7        133
# 889   1.759304e+09  C2ZB3K2kf5v7tjRr16  fe80::f2a4:8a20:4403:72b7        133
# 1001  1.759305e+09  CJYH9V2qOKJL8SMGR7  fe80::f2a4:8a20:4403:72b7        133
# 1149  1.759304e+09   C14KWbkn3ETv8y955  fe80::f2a4:8a20:4403:72b7        133
# 1162  1.759305e+09  Cl9xNg25J8dS3ord9k  fe80::f2a4:8a20:4403:72b7        133
# 1258  1.759303e+09  Cdnjth23i8ncwZkD02  fe80::f2a4:8a20:4403:72b7        133
# 1701  1.759304e+09   CuLfntxNwX0pS0ZH6  fe80::f2a4:8a20:4403:72b7        133
# 2121  1.759302e+09  CCjfQP1GaNBKTHyA25  fe80::f2a4:8a20:4403:72b7        133
# 2140  1.759302e+09  Cpu2n84eIQMtOqpDmb  fe80::f2a4:8a20:4403:72b7        133
# 2244  1.759302e+09  CFtuhl34eZmZY6NXke  fe80::f2a4:8a20:4403:72b7        133
# 2291  1.759302e+09  CD0iUO1qHmq9G7MM1a  fe80::f2a4:8a20:4403:72b7        133
# 2438  1.759295e+09  CHdOru3DSTpTx8Pkn3  fe80::f2a4:8a20:4403:72b7        133
# 2491  1.759296e+09  CoW5Sy4ePyI3WvZVs3  fe80::f2a4:8a20:4403:72b7        133
# 2720  1.759295e+09   CQcdAL2ZKzjh7Gizf  fe80::f2a4:8a20:4403:72b7        133
# 2993  1.759291e+09  CfPB6L3O8r534GA6Jc  fe80::f2a4:8a20:4403:72b7        133
# 3478  1.759294e+09   CzhJxnm3aukmZZHN8  fe80::f2a4:8a20:4403:72b7        133
# 3576  1.759294e+09  CE3yRE3O1fQkpQoX0e  fe80::f2a4:8a20:4403:72b7        133
# 3648  1.759294e+09   CQAoXpIfHGNqYKVpg  fe80::f2a4:8a20:4403:72b7        133
# 3755  1.759294e+09  CpXh5G30Wb9hCFLSr6  fe80::f2a4:8a20:4403:72b7        133
#
#      id.resp_h  id.resp_p proto service   duration  orig_bytes  ...  \
# 301    ff02::2        134  icmp     NaN        NaN         NaN  ...
# 716    ff02::2        134  icmp     NaN        NaN         NaN  ...
# 889    ff02::2        134  icmp     NaN        NaN         NaN  ...
# 1001   ff02::2        134  icmp     NaN        NaN         NaN  ...
# 1149   ff02::2        134  icmp     NaN        NaN         NaN  ...
# 1162   ff02::2        134  icmp     NaN        NaN         NaN  ...
# 1258   ff02::2        134  icmp     NaN        NaN         NaN  ...
# 1701   ff02::2        134  icmp     NaN  55.259391         0.0  ...
# 2121   ff02::2        134  icmp     NaN  60.183951         0.0  ...
# 2140   ff02::2        134  icmp     NaN        NaN         NaN  ...
# 2244   ff02::2        134  icmp     NaN        NaN         NaN  ...
# 2291   ff02::2        134  icmp     NaN        NaN         NaN  ...
# 2438   ff02::2        134  icmp     NaN        NaN         NaN  ...
# 2491   ff02::2        134  icmp     NaN        NaN         NaN  ...
# 2720   ff02::2        134  icmp     NaN        NaN         NaN  ...
# 2993   ff02::2        134  icmp     NaN        NaN         NaN  ...
# 3478   ff02::2        134  icmp     NaN        NaN         NaN  ...
# 3576   ff02::2        134  icmp     NaN        NaN         NaN  ...
# 3648   ff02::2        134  icmp     NaN        NaN         NaN  ...
# 3755   ff02::2        134  icmp     NaN  59.527209         0.0  ...
#
#       local_orig local_resp  missed_bytes  history  orig_pkts orig_ip_bytes  \
# 301         True      False             0      NaN          1            48
# 716         True      False             0      NaN          1            48
# 889         True      False             0      NaN          1            48
# 1001        True      False             0      NaN          1            48
# 1149        True      False             0      NaN          1            48
# 1162        True      False             0      NaN          1            48
# 1258        True      False             0      NaN          1            48
# 1701        True      False             0      NaN          5           240
# 2121        True      False             0      NaN          5           240
# 2140        True      False             0      NaN          1            48
# 2244        True      False             0      NaN          1            48
# 2291        True      False             0      NaN          1            48
# 2438        True      False             0      NaN          1            48
# 2491        True      False             0      NaN          1            48
# 2720        True      False             0      NaN          1            48
# 2993        True      False             0      NaN          1            48
# 3478        True      False             0      NaN          1            48
# 3576        True      False             0      NaN          1            48
# 3648        True      False             0      NaN          1            48
# 3755        True      False             0      NaN          5           240
#
#       resp_pkts  resp_ip_bytes                    community_id  orig_mac_oui
# 301           0              0  1:u6GMVmmWqsqSIHFj+HtD4i9wKH4=     Dell Inc.
# 716           0              0  1:u6GMVmmWqsqSIHFj+HtD4i9wKH4=     Dell Inc.
# 889           0              0  1:u6GMVmmWqsqSIHFj+HtD4i9wKH4=     Dell Inc.
# 1001          0              0  1:u6GMVmmWqsqSIHFj+HtD4i9wKH4=     Dell Inc.
# 1149          0              0  1:u6GMVmmWqsqSIHFj+HtD4i9wKH4=     Dell Inc.
# 1162          0              0  1:u6GMVmmWqsqSIHFj+HtD4i9wKH4=     Dell Inc.
# 1258          0              0  1:u6GMVmmWqsqSIHFj+HtD4i9wKH4=     Dell Inc.
# 1701          0              0  1:u6GMVmmWqsqSIHFj+HtD4i9wKH4=     Dell Inc.
# 2121          0              0  1:u6GMVmmWqsqSIHFj+HtD4i9wKH4=     Dell Inc.
# 2140          0              0  1:u6GMVmmWqsqSIHFj+HtD4i9wKH4=     Dell Inc.
# 2244          0              0  1:u6GMVmmWqsqSIHFj+HtD4i9wKH4=     Dell Inc.
# 2291          0              0  1:u6GMVmmWqsqSIHFj+HtD4i9wKH4=     Dell Inc.
# 2438          0              0  1:u6GMVmmWqsqSIHFj+HtD4i9wKH4=     Dell Inc.
# 2491          0              0  1:u6GMVmmWqsqSIHFj+HtD4i9wKH4=     Dell Inc.
# 2720          0              0  1:u6GMVmmWqsqSIHFj+HtD4i9wKH4=     Dell Inc.
# 2993          0              0  1:u6GMVmmWqsqSIHFj+HtD4i9wKH4=     Dell Inc.
# 3478          0              0  1:u6GMVmmWqsqSIHFj+HtD4i9wKH4=     Dell Inc.
# 3576          0              0  1:u6GMVmmWqsqSIHFj+HtD4i9wKH4=     Dell Inc.
# 3648          0              0  1:u6GMVmmWqsqSIHFj+HtD4i9wKH4=     Dell Inc.
# 3755          0              0  1:u6GMVmmWqsqSIHFj+HtD4i9wKH4=     Dell Inc.
#
# [20 rows x 22 columns]
# --------------------------------------------------
# Group: ('fe80::f2a4:8a20:4403:72b7', 'ff02::fb')
# Type: <class 'pandas.core.frame.DataFrame'>
#                 ts                 uid                  id.orig_h  id.orig_p  \
# 394   1.759306e+09   Cw1YHvx2Qsl2GIRnf  fe80::f2a4:8a20:4403:72b7       5353
# 777   1.759305e+09  CnME3A3ac3KnmcJVE7  fe80::f2a4:8a20:4403:72b7       5353
# 875   1.759304e+09  C04TcC4TC4hYfc5DAi  fe80::f2a4:8a20:4403:72b7       5353
# 930   1.759304e+09   CX83Uy1TKLAff73EJ  fe80::f2a4:8a20:4403:72b7       5353
# 999   1.759305e+09  Cf51Nx32EWV5trGKTf  fe80::f2a4:8a20:4403:72b7       5353
# 1619  1.759304e+09  CLra2I11FYCLPVRgBi  fe80::f2a4:8a20:4403:72b7       5353
# 1687  1.759304e+09   CsdMIs22bl1KaFO1M  fe80::f2a4:8a20:4403:72b7       5353
# 1935  1.759303e+09  CVbdbd2yA0CHko1Rs2  fe80::f2a4:8a20:4403:72b7       5353
# 2065  1.759302e+09  C8ZTqO3Fx8oQ08d6D2  fe80::f2a4:8a20:4403:72b7       5353
# 2096  1.759302e+09  C8txlu22kSV4gZPznb  fe80::f2a4:8a20:4403:72b7       5353
# 2128  1.759302e+09  CQFkru3adhwefmOqN5  fe80::f2a4:8a20:4403:72b7       5353
# 2186  1.759302e+09  CJOhmE22El97kmtwC2  fe80::f2a4:8a20:4403:72b7       5353
# 2277  1.759302e+09   CBH6vEXZvC0qYTgjf  fe80::f2a4:8a20:4403:72b7       5353
# 2355  1.759295e+09  Cy9lXD4tx7kqXbVYTj  fe80::f2a4:8a20:4403:72b7       5353
# 2367  1.759295e+09  C0mEjm1OPrAIevRsO5  fe80::f2a4:8a20:4403:72b7       5353
# 2496  1.759296e+09  CR5bWj1XM0qQmoKTjh  fe80::f2a4:8a20:4403:72b7       5353
# 2502  1.759294e+09  CGiHIU18skUHaHVuz8  fe80::f2a4:8a20:4403:72b7       5353
# 2542  1.759294e+09  C2zfB94YAQGux2YYj7  fe80::f2a4:8a20:4403:72b7       5353
# 2813  1.759292e+09  CyfStb1fpwanGMlFAi  fe80::f2a4:8a20:4403:72b7       5353
# 2889  1.759291e+09  CXz4Fa3QFwMhFTJbV1  fe80::f2a4:8a20:4403:72b7       5353
# 3619  1.759294e+09  CbNKWa1mrpYNTZBqe3  fe80::f2a4:8a20:4403:72b7       5353
# 3708  1.759294e+09   CmbiHBcdhjCAhxhNb  fe80::f2a4:8a20:4403:72b7       5353
# 3723  1.759294e+09  CMJMcO2jzxlBLouOs6  fe80::f2a4:8a20:4403:72b7       5353
#
#      id.resp_h  id.resp_p proto service   duration  orig_bytes  ...  \
# 394   ff02::fb       5353   udp     dns        NaN         NaN  ...
# 777   ff02::fb       5353   udp     dns        NaN         NaN  ...
# 875   ff02::fb       5353   udp     dns        NaN         NaN  ...
# 930   ff02::fb       5353   udp     dns        NaN         NaN  ...
# 999   ff02::fb       5353   udp     dns        NaN         NaN  ...
# 1619  ff02::fb       5353   udp     dns  29.148570       838.0  ...
# 1687  ff02::fb       5353   udp     dns        NaN         NaN  ...
# 1935  ff02::fb       5353   udp     dns        NaN         NaN  ...
# 2065  ff02::fb       5353   udp     dns  29.198855       838.0  ...
# 2096  ff02::fb       5353   udp     dns        NaN         NaN  ...
# 2128  ff02::fb       5353   udp     dns        NaN         NaN  ...
# 2186  ff02::fb       5353   udp     dns        NaN         NaN  ...
# 2277  ff02::fb       5353   udp     dns        NaN         NaN  ...
# 2355  ff02::fb       5353   udp     dns        NaN         NaN  ...
# 2367  ff02::fb       5353   udp     dns        NaN         NaN  ...
# 2496  ff02::fb       5353   udp     dns        NaN         NaN  ...
# 2502  ff02::fb       5353   udp     dns        NaN         NaN  ...
# 2542  ff02::fb       5353   udp     dns        NaN         NaN  ...
# 2813  ff02::fb       5353   udp     dns        NaN         NaN  ...
# 2889  ff02::fb       5353   udp     dns        NaN         NaN  ...
# 3619  ff02::fb       5353   udp     dns   0.978963       278.0  ...
# 3708  ff02::fb       5353   udp     dns  30.024651       979.0  ...
# 3723  ff02::fb       5353   udp     dns        NaN         NaN  ...
#
#       local_orig local_resp  missed_bytes  history  orig_pkts orig_ip_bytes  \
# 394         True      False             0        D          1           189
# 777         True      False             0        D          1           189
# 875         True      False             0        D          1           189
# 930         True      False             0        D          1           189
# 999         True      False             0        D          1           189
# 1619        True      False             0        D          6          1126
# 1687        True      False             0        D          1           189
# 1935        True      False             0        D          1           189
# 2065        True      False             0        D          6          1126
# 2096        True      False             0        D          1           189
# 2128        True      False             0        D          1           189
# 2186        True      False             0        D          1           189
# 2277        True      False             0        D          1           189
# 2355        True      False             0        D          1           189
# 2367        True      False             0        D          1           189
# 2496        True      False             0        D          1           189
# 2502        True      False             0        D          1           189
# 2542        True      False             0        D          1           189
# 2813        True      False             0        D          1           166
# 2889        True      False             0        D          1            93
# 3619        True      False             0        D          2           374
# 3708        True      False             0        D          7          1315
# 3723        True      False             0        D          1           189
#
#       resp_pkts  resp_ip_bytes                    community_id  orig_mac_oui
# 394           0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 777           0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 875           0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 930           0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 999           0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 1619          0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 1687          0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 1935          0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 2065          0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 2096          0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 2128          0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 2186          0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 2277          0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 2355          0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 2367          0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 2496          0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 2502          0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 2542          0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 2813          0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 2889          0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 3619          0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 3708          0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
# 3723          0              0  1:w/UZbYS+EDgwqu7rj67Idv/nOBM=     Dell Inc.
#
# [23 rows x 22 columns]
# --------------------------------------------------

# %%
http_df[http_df['uid'] == 'CxKH7z3wLoQuRZL2Hg']
# Out:
#               ts                 uid id.orig_h  id.orig_p id.resp_h  \
# 20  1.759308e+09  CxKH7z3wLoQuRZL2Hg  10.0.0.2      53240  10.0.0.1
# 21  1.759308e+09  CxKH7z3wLoQuRZL2Hg  10.0.0.2      53240  10.0.0.1
#
#     id.resp_p  trans_depth method      host  \
# 20         80            2    GET  10.0.0.1
# 21         80            1   POST  10.0.0.1
#
#                                                   uri  ... response_body_len  \
# 20                   /umd/bootstrap.min.js?b=889e4124  ...               115
# 21  /namespaces/oauth2callback/api/database/sample...  ...                 0
#
#    status_code  status_msg  tags           resp_fuids resp_mime_types  \
# 20       200.0          OK    []  [FgvVppa1JCACjhKMk]    [text/plain]
# 21       202.0    Accepted    []                  NaN             NaN
#
#               orig_fuids orig_mime_types resp_filenames referrer
# 20                   NaN             NaN            NaN      NaN
# 21  [FH7Kh34X7inbu7uUEk]    [text/plain]            NaN      NaN
#
# [2 rows x 23 columns]

# %%
dns_df[dns_df['uid'] == 'CtdMFy1XrFb9tm4Q93']
# Out:
#              ts                 uid id.orig_h  id.orig_p id.resp_h  id.resp_p  \
# 5  1.759309e+09  CtdMFy1XrFb9tm4Q93  10.0.0.1      59898   8.8.8.8         53
#
#   proto  trans_id  rcode rcode_name  ...  Z  rejected       rtt  \
# 5   udp     32360    0.0    NOERROR  ...  0     False  0.007364
#
#                       query  qclass  qclass_name  qtype qtype_name  \
# 5  gce-beacons.gcp.gvt2.com     1.0   C_INTERNET    1.0          A
#
#             answers   TTLs
# 5  [35.201.102.154]  [7.0]
#
# [1 rows x 24 columns]

# %%
http_df
# Out:
#                ts                 uid id.orig_h  id.orig_p       id.resp_h  \
# 0    1.759309e+09  Cdc5bG2hkz0ILUl65g  10.0.0.2      40686        10.0.0.1
# 1    1.759309e+09  Cdc5bG2hkz0ILUl65g  10.0.0.2      40686        10.0.0.1
# 2    1.759308e+09  CLodDc1igywiw9L6L8  10.0.0.2      46376        10.0.0.1
# 3    1.759308e+09  CLodDc1igywiw9L6L8  10.0.0.2      46376        10.0.0.1
# 4    1.759308e+09  CjTCER2Xu867CeeDk6  10.0.0.1      59818    91.189.91.49
# ..            ...                 ...       ...        ...             ...
# 556  1.759294e+09  CL7BqR29jNxoDDrEea  10.0.0.1      52610    91.189.91.96
# 557  1.759294e+09  CZTy5O1H4AFtj7lacb  10.0.0.1      34276    91.189.91.48
# 558  1.759294e+09  CnXHnO2stwZZtDett7  10.0.0.1      59742  185.125.190.17
# 559  1.759294e+09  CkEq6x2OSf3gc8NG16  10.0.0.2      59196        10.0.0.1
# 560  1.759294e+09  CkEq6x2OSf3gc8NG16  10.0.0.2      59196        10.0.0.1
#
#      id.resp_p  trans_depth method                            host  \
# 0           80            2    GET                        10.0.0.1
# 1           80            1   POST                        10.0.0.1
# 2           80            1   POST                        10.0.0.1
# 3           80            2    GET                        10.0.0.1
# 4           80            1    GET  connectivity-check.ubuntu.com.
# ..         ...          ...    ...                             ...
# 556         80            1    GET  connectivity-check.ubuntu.com.
# 557         80            1    GET  connectivity-check.ubuntu.com.
# 558         80            1    GET  connectivity-check.ubuntu.com.
# 559         80            2    GET                        10.0.0.1
# 560         80            1   POST                        10.0.0.1
#
#                                                    uri  ... response_body_len  \
# 0                                 /email.js?h=54761203  ...                78
# 1                       /db/php/samples.php?q=36b31298  ...                 0
# 2                             /samples.php?n=x63523274  ...                 0
# 3                         /bootstrap.min.js?x=32584987  ...               115
# 4                                                    /  ...                 0
# ..                                                 ...  ...               ...
# 556                                                  /  ...                 0
# 557                                                  /  ...                 0
# 558                                                  /  ...                 0
# 559  /bundles/assets/javascript/assets/jscript/asse...  ...               115
# 560  /namespaces/db/oauth2callback/oauth2/oauth/sam...  ...                 0
#
#     status_code  status_msg  tags            resp_fuids resp_mime_types  \
# 0         200.0          OK    []  [F5z7tE1XSpgAqPbVxh]    [text/plain]
# 1         202.0    Accepted    []                   NaN             NaN
# 2         202.0    Accepted    []                   NaN             NaN
# 3         200.0          OK    []  [F4zUUC2IXNkDKA4lTj]    [text/plain]
# 4         204.0  No Content    []                   NaN             NaN
# ..          ...         ...   ...                   ...             ...
# 556       204.0  No Content    []                   NaN             NaN
# 557       204.0  No Content    []                   NaN             NaN
# 558       204.0  No Content    []                   NaN             NaN
# 559       200.0          OK    []  [FpTP8F1eOy7i4CblPg]    [text/plain]
# 560       202.0    Accepted    []                   NaN             NaN
#
#                orig_fuids       orig_mime_types resp_filenames referrer
# 0                     NaN                   NaN            NaN      NaN
# 1    [F1CP3c34NJm45ETYi7]  [application/x-gzip]            NaN      NaN
# 2    [Fu4rZa3YZo6hHkRlVa]          [text/plain]            NaN      NaN
# 3                     NaN                   NaN            NaN      NaN
# 4                     NaN                   NaN            NaN      NaN
# ..                    ...                   ...            ...      ...
# 556                   NaN                   NaN            NaN      NaN
# 557                   NaN                   NaN            NaN      NaN
# 558                   NaN                   NaN            NaN      NaN
# 559                   NaN                   NaN            NaN      NaN
# 560  [Fv2AAP3FUdYu1Mx27k]  [application/x-gzip]            NaN      NaN
#
# [561 rows x 23 columns]

# %%
dns_df
# Out:
#                 ts                 uid id.orig_h  id.orig_p id.resp_h  \
# 0     1.759309e+09  C0Rdwk31xuJYQSlgrg  10.0.0.1      50105   8.8.8.8
# 1     1.759309e+09  Cqo8MK2eavjXseZeDc  10.0.0.1      42392   8.8.8.8
# 2     1.759309e+09  CBC10k1kjJeX7o7W1g  10.0.0.1      44598   8.8.8.8
# 3     1.759309e+09   CIP2fmcle0a3mRVdl  10.0.0.1      35911   8.8.8.8
# 4     1.759309e+09  CBC10k1kjJeX7o7W1g  10.0.0.1      44598   8.8.8.8
# ...            ...                 ...       ...        ...       ...
# 2763  1.759294e+09  CIbjK24zpMBX6TcGOe  10.0.0.1      42260   8.8.8.8
# 2764  1.759294e+09   CP2RUQrFo1qIvTZQ7  10.0.0.1      59283   8.8.8.8
# 2765  1.759294e+09  Ci50uY1KnvqZit7Wrg  10.0.0.1      49377   8.8.8.8
# 2766  1.759294e+09  CTHr0P2ROyjI3QUA3f  10.0.0.1      34175   8.8.8.8
# 2767  1.759294e+09  CdLRLM23HI3n9QpER9  10.0.0.1      59060   8.8.8.8
#
#       id.resp_p proto  trans_id  rcode rcode_name  ...  Z  rejected       rtt  \
# 0            53   udp      3387    5.0    REFUSED  ...  0      True       NaN
# 1            53   udp     22853    0.0    NOERROR  ...  0     False  0.006600
# 2            53   udp     13057    0.0    NOERROR  ...  0     False       NaN
# 3            53   udp     51985    0.0    NOERROR  ...  0     False  0.006069
# 4            53   udp     13057    5.0    REFUSED  ...  0      True       NaN
# ...         ...   ...       ...    ...        ...  ... ..       ...       ...
# 2763         53   udp     13898    5.0    REFUSED  ...  0      True       NaN
# 2764         53   udp     30982    0.0    NOERROR  ...  0     False  0.007765
# 2765         53   udp     61751    0.0    NOERROR  ...  0     False       NaN
# 2766         53   udp     63046    0.0    NOERROR  ...  0     False       NaN
# 2767         53   udp     13551    0.0    NOERROR  ...  0     False       NaN
#
#                                            query  qclass  qclass_name  qtype  \
# 0                                            NaN     NaN          NaN    NaN
# 1               mobile.events.data.microsoft.com     1.0   C_INTERNET    1.0
# 2     onedscolprdwus03.westus.cloudapp.azure.com     1.0   C_INTERNET   28.0
# 3               mobile.events.data.microsoft.com     1.0   C_INTERNET   28.0
# 4                                            NaN     NaN          NaN    NaN
# ...                                          ...     ...          ...    ...
# 2763                                         NaN     NaN          NaN    NaN
# 2764                            beacons.gvt2.com     1.0   C_INTERNET    1.0
# 2765                            beacons.gvt2.com     1.0   C_INTERNET   65.0
# 2766                 translate-pa.googleapis.com     1.0   C_INTERNET   65.0
# 2767                             ssl.gstatic.com     1.0   C_INTERNET   65.0
#
#      qtype_name                                            answers  \
# 0           NaN                                                NaN
# 1             A  [mobile.events.data.trafficmanager.net, onedsc...
# 2          AAAA                                                NaN
# 3          AAAA  [mobile.events.data.trafficmanager.net, onedsc...
# 4           NaN                                                NaN
# ...         ...                                                ...
# 2763        NaN                                                NaN
# 2764          A                                   [172.217.194.94]
# 2765      HTTPS                                                NaN
# 2766      HTTPS                                                NaN
# 2767      HTTPS                                                NaN
#
#                    TTLs
# 0                   NaN
# 1     [93.0, 39.0, 0.0]
# 2                   NaN
# 3          [93.0, 44.0]
# 4                   NaN
# ...                 ...
# 2763                NaN
# 2764             [92.0]
# 2765                NaN
# 2766                NaN
# 2767                NaN
#
# [2768 rows x 24 columns]

# %%
ssl_df
# Out:
#                 ts                 uid id.orig_h  id.orig_p       id.resp_h  \
# 0     1.759309e+09  CRJ0Ul4cRvaD99FQRa  10.0.0.1      44002   20.50.201.195
# 1     1.759308e+09  CNkt0V1GHVBqgODD09  10.0.0.1      34626  172.253.118.94
# 2     1.759308e+09  CDiGoe3xtzlulY0GRh  10.0.0.1      60921   142.251.10.94
# 3     1.759308e+09  CO72kE3olhAr6Uji8i  10.0.0.1      58399    142.250.4.94
# 4     1.759308e+09   C2Pj4ieQIILhGLpj8  10.0.0.1      47752    74.125.68.94
# ...            ...                 ...       ...        ...             ...
# 1342  1.759294e+09   CvCoIbPlXWHaBnC69  10.0.0.1      39553  142.251.10.148
# 1343  1.759294e+09  CAFEZg2Osfn3muPNi2  10.0.0.1      60772  64.233.170.154
# 1344  1.759294e+09  CpXvTu1h5za7BXDyDj  10.0.0.1      45783   142.251.10.84
# 1345  1.759294e+09   CC1lrqeMwxu2wPZP6  10.0.0.1      60035  142.251.10.139
# 1346  1.759294e+09  ClcdGp22MRpQEslMO1  10.0.0.1      40466  172.253.118.95
#
#       id.resp_p version                  cipher         curve  \
# 0           443  TLSv13  TLS_AES_256_GCM_SHA384     secp384r1
# 1           443  TLSv13  TLS_AES_128_GCM_SHA256  unknown-4588
# 2           443  TLSv13  TLS_AES_128_GCM_SHA256  unknown-4588
# 3           443  TLSv13  TLS_AES_128_GCM_SHA256  unknown-4588
# 4           443  TLSv13  TLS_AES_128_GCM_SHA256  unknown-4588
# ...         ...     ...                     ...           ...
# 1342        443  TLSv13  TLS_AES_128_GCM_SHA256  unknown-4588
# 1343        443  TLSv13  TLS_AES_128_GCM_SHA256  unknown-4588
# 1344        443  TLSv13  TLS_AES_128_GCM_SHA256  unknown-4588
# 1345        443  TLSv13  TLS_AES_128_GCM_SHA256  unknown-4588
# 1346        443  TLSv13  TLS_AES_128_GCM_SHA256  unknown-4588
#
#                            server_name  ...  ssl_history  \
# 0     mobile.events.data.microsoft.com  ...       CjiICs
# 1                      ssl.gstatic.com  ...           Cs
# 2                          b1.nel.goog  ...           Cs
# 3                 beacons.gcp.gvt2.com  ...           Cs
# 4                     beacons.gvt2.com  ...           Cs
# ...                                ...  ...          ...
# 1342            static.doubleclick.net  ...           Cs
# 1343          www.googleadservices.com  ...           Cs
# 1344               accounts.google.com  ...           Cs
# 1345        encrypted-tbn0.gstatic.com  ...           Cs
# 1346      ogads-pa.clients6.google.com  ...           Cs
#
#                                    ja3                              ja3s  \
# 0     06c7c8851b69f67e31df21d5075e2dfd  46ca3a127f5443353dfb8cc2e16197e5
# 1     c957bef0eaca4e029c38b8f9e10f86e9  2b0648ab686ee45e0e7c35fcfb0eea7e
# 2     1873ef5726ca0100f77c7f7afd49dde1  2b0648ab686ee45e0e7c35fcfb0eea7e
# 3     26a52527618ebefc4e67a8ad88485334  eb1d94daa7e0344597e756a1fb6e7054
# 4     22002d4bc8265c654dc8871b2da038a3  2b0648ab686ee45e0e7c35fcfb0eea7e
# ...                                ...                               ...
# 1342  1850d9300f4bfff1aea5f65aed483fd6  2b0648ab686ee45e0e7c35fcfb0eea7e
# 1343  5cd80cd6db0cda7cdbbf4d03813a10a9  2b0648ab686ee45e0e7c35fcfb0eea7e
# 1344  57a3472a1d8ace163680ae31ee357068  2b0648ab686ee45e0e7c35fcfb0eea7e
# 1345  8546dd690103577886665ef2b9d27fea  2b0648ab686ee45e0e7c35fcfb0eea7e
# 1346  1b028fc325f149bd19fd3ff641954f49  2b0648ab686ee45e0e7c35fcfb0eea7e
#
#                                        ja4                    community_id  \
# 0     t13d181200_5d04281c6031_02c8e53ee398  1:3qDKx3qLPrh2l5WHAKZGic4MtH8=
# 1     q13d0313h3_55b375c5d22e_226f3f127bbe                             NaN
# 2     q13d0313h3_55b375c5d22e_226f3f127bbe                             NaN
# 3     q13d0312h3_55b375c5d22e_5a06198afb93                             NaN
# 4     q13d0313h3_55b375c5d22e_226f3f127bbe                             NaN
# ...                                    ...                             ...
# 1342  q13d0313h3_55b375c5d22e_226f3f127bbe                             NaN
# 1343  q13d0313h3_55b375c5d22e_226f3f127bbe                             NaN
# 1344  q13d0313h3_55b375c5d22e_226f3f127bbe                             NaN
# 1345  q13d0313h3_55b375c5d22e_226f3f127bbe                             NaN
# 1346  q13d0313h3_55b375c5d22e_226f3f127bbe                             NaN
#
#      cert_chain_fps client_cert_chain_fps sni_matches_cert validation_status  \
# 0               NaN                   NaN              NaN               NaN
# 1               NaN                   NaN              NaN               NaN
# 2               NaN                   NaN              NaN               NaN
# 3               NaN                   NaN              NaN               NaN
# 4               NaN                   NaN              NaN               NaN
# ...             ...                   ...              ...               ...
# 1342            NaN                   NaN              NaN               NaN
# 1343            NaN                   NaN              NaN               NaN
# 1344            NaN                   NaN              NaN               NaN
# 1345            NaN                   NaN              NaN               NaN
# 1346            NaN                   NaN              NaN               NaN
#
#      next_protocol
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 1342           NaN
# 1343           NaN
# 1344           NaN
# 1345           NaN
# 1346           NaN
#
# [1347 rows x 22 columns]

# %%
# print row with id.orig_h == '10.0.0.2' and id.resp_h == '10.0.0.1'
conn_df[(conn_df['id.orig_h'] == '10.0.0.2') & (conn_df['id.resp_h'] == '10.0.0.1')]
# Out:
#                 ts                 uid id.orig_h  id.orig_p id.resp_h  \
# 2     1.759308e+09  CxKH7z3wLoQuRZL2Hg  10.0.0.2      53240  10.0.0.1
# 25    1.759307e+09  Cgilh11U5OoqnQ4Ill  10.0.0.2      48390  10.0.0.1
# 40    1.759307e+09  CEpCtn3lPNMIP50DUh  10.0.0.2      54828  10.0.0.1
# 61    1.759307e+09  C95P6m49XPf3rf2X14  10.0.0.2      52594  10.0.0.1
# 105   1.759306e+09  CsP8M01v0Wjz8NLkg4  10.0.0.2      40586  10.0.0.1
# ...            ...                 ...       ...        ...       ...
# 3260  1.759294e+09  Cd1LFV29IuUJLSbca7  10.0.0.2      36468  10.0.0.1
# 3272  1.759294e+09    CB5ttKIfHS0ljc34  10.0.0.2      53726  10.0.0.1
# 3310  1.759294e+09   CP80Tb2RF6buF6wmS  10.0.0.2      47292  10.0.0.1
# 3342  1.759294e+09   CkoHP7QIRsMwfHMJb  10.0.0.2      50558  10.0.0.1
# 3423  1.759294e+09  Cv8OL64H0Aw5cno8s8  10.0.0.2      59518  10.0.0.1
#
#       id.resp_p proto service  duration  orig_bytes  ...  local_orig  \
# 2            80   tcp    http  0.005332      1012.0  ...        True
# 25           80   tcp    http  0.005532      1372.0  ...        True
# 40           80   tcp    http  0.005971      1034.0  ...        True
# 61           80   tcp    http  0.005671       981.0  ...        True
# 105          80   tcp    http  0.010302       936.0  ...        True
# ...         ...   ...     ...       ...         ...  ...         ...
# 3260         80   tcp    http  0.006310      1370.0  ...        True
# 3272         80   tcp    http  0.004807      1800.0  ...        True
# 3310         80   tcp    http  0.005416      1050.0  ...        True
# 3342         80   tcp    http  0.003716       477.0  ...        True
# 3423        443   tcp     NaN  0.000090         0.0  ...        True
#
#      local_resp  missed_bytes   history  orig_pkts orig_ip_bytes  resp_pkts  \
# 2          True             0  ShADadFf          7          1384          5
# 25         True             0  ShADadFf          7          1744          5
# 40         True             0  ShADadFf          7          1406          5
# 61         True             0  ShADadFf          7          1353          5
# 105        True             0  ShADadFf          7          1308          5
# ...         ...           ...       ...        ...           ...        ...
# 3260       True             0  ShADadFf          7          1742          5
# 3272       True             0  ShADadFf          7          2172          5
# 3310       True             0  ShADadFf          7          1422          5
# 3342       True             0  ShADadFf          6           797          4
# 3423       True             0        Sr          1            60          1
#
#       resp_ip_bytes                    community_id  \
# 2               582  1:mRIxvo4BIbYvxwZeb5LX99Bjq+4=
# 25              544  1:pXSSH5V9PnwN3OoesoFjYnkaEPk=
# 40             1066  1:jazkOBgVKy0WnD61aOZmprLVCUo=
# 61              828  1:4+MU8NYlLQCnmgGzMgTTOWMyOug=
# 105            1065  1:XlpJbSRxRGPwOKO5a8/iWrReGz8=
# ...             ...                             ...
# 3260            583  1:kVpei6SJDLUr+mQWjmA7Zj8E/QM=
# 3272            582  1:vw9EjJPwyFKCHaMkyzZRgEnokNk=
# 3310            544  1:BAGlHbStjrsg3nP5KUQ2kZkUaQQ=
# 3342            364  1:4ABH3J1mHBctDvMJBwcrdsnikEs=
# 3423             40  1:EUzqx4xO8WWitxUttaGtoRY32H8=
#
#                                      orig_mac_oui
# 2     LCFC(Hefei) Electronics Technology co., ltd
# 25    LCFC(Hefei) Electronics Technology co., ltd
# 40    LCFC(Hefei) Electronics Technology co., ltd
# 61    LCFC(Hefei) Electronics Technology co., ltd
# 105   LCFC(Hefei) Electronics Technology co., ltd
# ...                                           ...
# 3260  LCFC(Hefei) Electronics Technology co., ltd
# 3272  LCFC(Hefei) Electronics Technology co., ltd
# 3310  LCFC(Hefei) Electronics Technology co., ltd
# 3342  LCFC(Hefei) Electronics Technology co., ltd
# 3423  LCFC(Hefei) Electronics Technology co., ltd
#
# [155 rows x 22 columns]

# %%
# muc do phan bo doi xung quanh trung vi
def calc_bowley_skewness(data):
    if len(data) < 3:
        return 0.0
    
    q1, q2, q3 = np.percentile(data, [25, 50, 75])

    if (q3 - q1) == 0:
        return 0.0
    
    bowley_skewness = (q3 + q1 - 2 * q2) / (q3 - q1)
    score = abs(bowley_skewness)
    return score

# %%
# muc do phan tan xung quanh trung vi
def calc_median_absolute_deviation(data):
    if len(data) == 0:
        return 0.0

    mad = np.median(np.abs(data - np.median(data)))
    score = mad
    return score

# %%
def calc_auto_correlation(data, lag=1):
    if len(data) < lag + 1:
        return 0.0

    n = len(data)
    mean = np.mean(data)
    c_lag = np.sum((data[:n - lag] - mean) * (data[lag:] - mean))
    c0 = np.sum((data - mean) ** 2)

    if c0 == 0:
        return 0.0

    autocorr = c_lag / c0
    score = abs(autocorr)
    return score
